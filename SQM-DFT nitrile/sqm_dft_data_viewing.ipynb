# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
qsm_raw = pd.read_table('./sqm_data.dat',delim_whitespace=True,header=12)
dft_raw = pd.read_table('./dft_data.dat',delim_whitespace=True,header=1)

# %%
qsm_raw.describe()
# Out:
#            HOMO/eV      LUMO/eV         n/cP         Tb/K         Tf/K  \
# count  4897.000000  4897.000000  4897.000000  4897.000000  4897.000000
# mean    -10.819877     0.721506     2.998571   567.330895   373.977829
# std       0.720321     0.580480     3.303164    52.449718    31.352858
# min     -13.639000    -2.037000     0.336700   338.050000   239.223000
# 25%     -11.179000     0.668000     1.925110   536.221000   356.115000
# 50%     -10.902000     0.987000     2.425990   559.984000   368.230000
# 75%     -10.709000     1.029000     3.157050   582.856000   383.785000
# max      -7.790000     1.162000   100.686720   999.667000   616.850000
#
#               Tm/K  DeltaGsolv-Li-kcal/mol  DeltaGsolv-pf6-kcal/mol
# count  4897.000000             4897.000000              4897.000000
# mean     32.081152             -122.591325               -49.120428
# std      36.838021                1.123439                 1.246457
# ...

# %%
sns.pairplot(qsm_raw)

# %%
dft_raw.describe()
# Out:
#             IP/eV        n/cP        Tb/K        Tf/K  mu(Li)/(keal/mol)  \
# count  422.000000  422.000000  422.000000  422.000000         422.000000
# mean    -8.084005    7.824431  614.647322  415.781706          17.340427
# std      0.721562    9.157266   83.495168   53.200643           1.346975
# min    -11.600000    0.250000  268.240000  189.510000          15.240000
# 25%     -8.470000    2.622500  562.135000  383.190000          16.215000
# 50%     -8.100000    4.190000  619.820000  418.900000          17.125000
# 75%     -7.792500    9.802500  674.557500  452.505000          18.140000
# max     -6.280000   93.690000  813.860000  537.660000          23.320000
#
#        mu(PF6-)/(kcal/mol)
# count           422.000000
# mean              1.232948
# std               1.036213
# min              -1.590000
# 25%               0.517500
# 50%               1.290000
# 75%               1.927500
# max               3.950000

# %%
sns.pairplot(dft_raw)
